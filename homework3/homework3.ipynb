# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("./course_lead_scoring.csv")

df.sample(5)
# Out:
#          lead_source       industry  number_of_courses_viewed  annual_income  \
# 1250          events          other                         3            NaN
# 477           events  manufacturing                         0        57134.0
# 239     social_media     healthcare                         3            NaN
# 1085  organic_search         retail                         1        59195.0
# 427         referral     healthcare                         0        70164.0
#
#      employment_status       location  interaction_count  lead_score  \
# 1250     self_employed           asia                  1        0.65
# 477      self_employed  north_america                  4        0.13
# 239      self_employed         africa                  2        0.36
# 1085           student           asia                  0        0.39
# 427           employed           asia                  4        0.35
#
#       converted
# 1250          0
# 477           0
# 239           0
# 1085          0
# 427           0

# %% [markdown]
# ## Q1
# Most Frequent Observation Mode for column industry

# %%
df['industry'].mode()
# Out:
# 0    retail
# Name: industry, dtype: object

# %%
df.describe(include='all')
# Out:
#            lead_source industry  number_of_courses_viewed  annual_income  \
# count             1334     1328               1462.000000    1281.000000
# unique               5        7                       NaN            NaN
# top     organic_search   retail                       NaN            NaN
# freq               282      203                       NaN            NaN
# mean               NaN      NaN                  2.031464   59886.273224
# std                NaN      NaN                  1.449717   15070.140389
# min                NaN      NaN                  0.000000   13929.000000
# 25%                NaN      NaN                  1.000000   49698.000000
# 50%                NaN      NaN                  2.000000   60148.000000
# 75%                NaN      NaN                  3.000000   69639.000000
# max                NaN      NaN                  9.000000  109899.000000
#
#        employment_status       location  interaction_count   lead_score  \
# count               1362           1399        1462.000000  1462.000000
# unique                 4              7                NaN          NaN
# top        self_employed  north_america                NaN          NaN
# freq                 352            225                NaN          NaN
# mean                 NaN            NaN           2.976744     0.506108
# std                  NaN            NaN           1.681564     0.288465
# min                  NaN            NaN           0.000000     0.000000
# 25%                  NaN            NaN           2.000000     0.262500
# 50%                  NaN            NaN           3.000000     0.510000
# 75%                  NaN            NaN           4.000000     0.750000
# max                  NaN            NaN          11.000000     1.000000
#
#           converted
# count   1462.000000
# unique          NaN
# top             NaN
# freq            NaN
# mean       0.619015
# std        0.485795
# min        0.000000
# 25%        0.000000
# 50%        1.000000
# 75%        1.000000
# max        1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1462 entries, 0 to 1461
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   lead_source               1334 non-null   object
#  1   industry                  1328 non-null   object
#  2   number_of_courses_viewed  1462 non-null   int64
#  3   annual_income             1281 non-null   float64
#  4   employment_status         1362 non-null   object
#  5   location                  1399 non-null   object
#  6   interaction_count         1462 non-null   int64
#  7   lead_score                1462 non-null   float64
#  8   converted                 1462 non-null   int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 102.9+ KB

# %% [markdown]
# ## Q2
# Create the correlation matrix for the numerical features of your dataset. In a correlation matrix, you compute the correlation coefficient between every pair of features.

# %%
df[[i for i in df.columns if (df[i].dtype in ['int64', 'float64'])]].corr().round(2)
# Out:
#                           number_of_courses_viewed  annual_income  \
# number_of_courses_viewed                      1.00           0.03
# annual_income                                 0.03           1.00
# interaction_count                            -0.02           0.05
# lead_score                                   -0.00           0.01
# converted                                     0.44           0.08
#
#                           interaction_count  lead_score  converted
# number_of_courses_viewed              -0.02       -0.00       0.44
# annual_income                          0.05        0.01       0.08
# interaction_count                      1.00        0.01       0.37
# lead_score                             0.01        1.00       0.19
# converted                              0.37        0.19       1.00

# %% [markdown]
# ## Q3
#
# - Calculate the mutual information score between y and other categorical variables in the dataset. Use the training set only.
# - Round the scores to 2 decimals using round(score, 2).
#
# Which of these variables has the biggest mutual information score?
